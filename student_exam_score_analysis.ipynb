# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("student_exam_scores.csv")

# %%
df.rename(columns = {
    "sleep_hours" : "Sleep",
    "attendance_percent" :"Attendance",
    "previous_scores" :"Previous"} , inplace  =True)

# %%
A  = df.head()

# %%
A
# Out:
#   student_id  hours_studied  Sleep  Attendance  Previous  exam_score
# 0       S001            8.0    8.8        72.1        45        30.2
# 1       S002            1.3    8.6        60.7        55        25.0
# 2       S003            4.0    8.2        73.7        86        35.8
# 3       S004            3.5    4.8        95.1        66        34.0
# 4       S005            9.1    6.4        89.8        71        40.3

# %%
sns.lineplot(x  ="hours_studied", y="exam_score",data = df)
plt.title("how number of hours affect exam_scores")
plt.show()

# %%
df.describe()
# Out:
#        hours_studied       Sleep  Attendance    Previous  exam_score
# count     200.000000  200.000000  200.000000  200.000000  200.000000
# mean        6.325500    6.622000   74.830000   66.800000   33.955000
# std         3.227317    1.497138   14.249905   15.663869    6.789548
# min         1.000000    4.000000   50.300000   40.000000   17.100000
# 25%         3.500000    5.300000   62.200000   54.000000   29.500000
# 50%         6.150000    6.700000   75.250000   67.500000   34.050000
# 75%         9.000000    8.025000   87.425000   80.000000   38.750000
# max        12.000000    9.000000  100.000000   95.000000   51.300000

# %%
df.max()
# Out:
# student_id        S200
# hours_studied     12.0
# Sleep              9.0
# Attendance       100.0
# Previous            95
# exam_score        51.3
# dtype: object

# %%
df.min()
# Out:
# student_id       S001
# hours_studied     1.0
# Sleep             4.0
# Attendance       50.3
# Previous           40
# exam_score       17.1
# dtype: object

# %%
sns.lineplot(x  ="Sleep", y="exam_score",data = df)
plt.title("how number of hours affect exam_scores")
plt.show()

# %%
sns.lineplot(x  ="Attendance", y="exam_score",data = df)
plt.title("how number of hours affect exam_scores")
plt.show()

# %%
corr_matrix =df.corr()
print(corr_matrix)
# Out:
#                hours_studied     Sleep  Attendance  Previous  exam_score
# hours_studied       1.000000  0.077864   -0.031311  0.069078    0.776751
# Sleep               0.077864  1.000000    0.000572 -0.194251    0.188222
# Attendance         -0.031311  0.000572    1.000000  0.051958    0.225713
# Previous            0.069078 -0.194251    0.051958  1.000000    0.431105
# exam_score          0.776751  0.188222    0.225713  0.431105    1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.head()
# Out:
#    hours_studied  Sleep  Attendance  Previous  exam_score
# 0            8.0    8.8        72.1        45        30.2
# 1            1.3    8.6        60.7        55        25.0
# 2            4.0    8.2        73.7        86        35.8
# 3            3.5    4.8        95.1        66        34.0
# 4            9.1    6.4        89.8        71        40.3

# %%
df.isnull().sum()
# Out:
# hours_studied    0
# Sleep            0
# Attendance       0
# Previous         0
# exam_score       0
# dtype: int64

# %%
df.head()
# Out:
#    hours_studied  Sleep  Attendance  Previous  exam_score
# 0            8.0    8.8        72.1        45        30.2
# 1            1.3    8.6        60.7        55        25.0
# 2            4.0    8.2        73.7        86        35.8
# 3            3.5    4.8        95.1        66        34.0
# 4            9.1    6.4        89.8        71        40.3

# %%
df["exam_score"].mean()
# Out:
# 33.955

# %%
top_students = df.sort_values("exam_score" ,ascending =False).head(5) 
print(top_students)
# Out:
#      hours_studied  Sleep  Attendance  Previous  exam_score
# 86            12.0    8.2        71.0        95        51.3
# 83            10.9    5.3        87.7        88        48.9
# 60            11.9    8.4        53.9        78        48.6
# 120            9.4    8.3       100.0        78        47.9
# 71            11.4    5.5        77.1        85        47.9

# %%
bottom_students = df.sort_values("exam_score",ascending= False  ).tail(5)
print(bottom_students)
# Out:
#      hours_studied  Sleep  Attendance  Previous  exam_score
# 70             3.3    8.1        70.4        40        20.8
# 183            2.1    6.0        54.3        54        19.4
# 142            3.9    4.1        55.4        53        19.0
# 7              2.0    4.3        75.8        55        18.3
# 19             1.1    5.5        53.6        65        17.1

# %%
plt.figure(figsize=(8,6))
plt.hexbin(df["hours_studied"], df["exam_score"], gridsize=15)
plt.colorbar(label="Count")

plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Hexbin Plot: Hours Studied vs Exam Score")
plt.show()

# %%
A  =df.sort_values(by =["exam_score"], ascending  =False)

# %%
A
# Out:
#      hours_studied  Sleep  Attendance  Previous  exam_score
# 86            12.0    8.2        71.0        95        51.3
# 83            10.9    5.3        87.7        88        48.9
# 60            11.9    8.4        53.9        78        48.6
# 120            9.4    8.3       100.0        78        47.9
# 71            11.4    5.5        77.1        85        47.9
# ..             ...    ...         ...       ...         ...
# 70             3.3    8.1        70.4        40        20.8
# 183            2.1    6.0        54.3        54        19.4
# 142            3.9    4.1        55.4        53        19.0
# 7              2.0    4.3        75.8        55        18.3
# 19             1.1    5.5        53.6        65        17.1
#
# [200 rows x 5 columns]

# %%
#From the analysis of the data above we get to know that marks depends mostly on number of hours_studied but also on attendance. Though some students have have slept less and performed well but the students with proper sleep has scored more .
